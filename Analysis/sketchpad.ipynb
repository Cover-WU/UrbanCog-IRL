# %%
l = [0, 0, 1, 2, 3]

# %%
from itertools import combinations

c = list(combinations(l, 2))

# %%
c
# Out:
# [(0, 0),
#  (0, 1),
#  (0, 2),
#  (0, 3),
#  (0, 1),
#  (0, 2),
#  (0, 3),
#  (1, 2),
#  (1, 3),
#  (2, 3)]
